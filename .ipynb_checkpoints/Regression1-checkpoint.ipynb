# %%
import xlrd
import xlsxwriter

#open excel file
predata = xlrd.open_workbook('PreRegression.xlsx')
table_predata = predata.sheets()[0]

# %%
for i in range(0,table_predata.nrows):
    locals()['predata_'+str(i)] = table_predata.row_values(i)

for i in range(0,3276):
    locals()['predata_FundID_'+str(i+1)] = []
    locals()['predata_FundSize_'+str(i+1)] = []
    locals()['predata_FundFlow_'+str(i+1)] = []
    locals()['predata_FundReturn_'+str(i+1)] = []
    locals()['predata_FundSustainability_'+str(i+1)] = []

# %%
#there are 3276 funds
for i in range(0,3276):
    for j in range(0,92):
        locals()['predata_FundID_'+str(i+1)].append(table_predata.row_values(1+j+i*92)[1])
        locals()['predata_Fund_'+str(i+1)].append(table_predata.row_values(1+j+i*92)[1])
        locals()['predata_FundID_'+str(i+1)].append(table_predata.row_values(1+j+i*92)[1])
        locals()['predata_FundID_'+str(i+1)].append(table_predata.row_values(1+j+i*92)[1])
        locals()['predata_FundID_'+str(i+1)].append(table_predata.row_values(1+j+i*92)[1])

# %%
print(predata_FundID_3276)
# Out:
# ['FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF', 'FSUSA09WNF']
