# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
from linearmodels import PanelOLS
from linearmodels import PooledOLS

# %%
#Preparation, already finished

df_org = pd.read_excel('FinalVersion.xlsx')
snapshot = pd.read_excel('fund_snapshot_lux.xlsx')

cols = ['FundId', 'Month', 'Fund Size', 'Fund Flow', 'Fund Sustainability', 'CAPM Performance', 'Performance Three Factor', 'Performance Four Factor']
df = df_org[cols].replace({0:np.nan})

cols_snapshot = ['FundId', 'Inception Date', 'Equity Style Box (Long)']
snap = snapshot[cols_snapshot].replace({0:np.nan})

# %%
#snap join into the summary, the ages are calculated according to the inception date
joint = df.join(snap.set_index('FundId'), on='FundId')
age = (joint['Inception Date'] - pd.to_datetime(2019-8-1))/np.timedelta64(1,'M')
joint['Age'] = age

fund_size_log = np.log10(joint['Fund Size'])
joint['size_log'] = fund_size_log

#the joint is saved and the column name Fund Sustainability is changed because of the space
#joint.to_excel("joint_snap.xlsx")

# %%
joint = pd.read_excel('joint_snap.xlsx')

# %%
#convert the month column into correct form
joint['Month'] = pd.to_datetime(joint['Month'])
age = (joint['Month'] - joint['Inception Date'])/np.timedelta64(1,'M')
age = [int(i) for i in age]
joint['Age'] = age
#joint.dropna(subset=["esg_score"], inplace=True)

#convert the esb_l from string to float
esb_l = pd.DataFrame({'Equity Style Box (Long)':['Large Value', 'Large Growth', 'Large Blend', 'Mid Value', 'Mid Growth', 'Mid Blend','Small Value','Small Growth','Small Blend'], 'esb_l': [1, 2, 3, 4, 5, 6, 7, 8, 9]})
joint_new = joint.join(esb_l.set_index('Equity Style Box (Long)'), on='Equity Style Box (Long)')

# %%
#catagorize the month - 2012/01 to 2019/08, totoally 92 months
month = pd.Categorical(joint_new.Month)

#use the 'Month' to divide the dataset, the index is Fund ID
df = joint_new.set_index(['FundId', 'Month'])
df['Month'] = month

# %%
df
# Out:
#                           Fund Size     Fund Flow  Fund Sustainability  \
# FundId     Month
# FS00008SZD 2012-01-01  2.609599e+08  4.379443e+07                  NaN
#            2012-02-01  2.988403e+08  2.572761e+07                  NaN
#            2012-03-01  3.071028e+08  1.558167e+06                  NaN
#            2012-04-01  3.440745e+08  3.753147e+07                  NaN
#            2012-05-01  3.771187e+08  4.877692e+07                  NaN
# ...                             ...           ...                  ...
# FSUSA09WNF 2019-04-01  8.137770e+06 -1.487095e+03                  NaN
#            2019-05-01  7.979041e+06  8.084123e+02                  NaN
#            2019-06-01  8.651099e+06  2.060187e+03                40.91
#            2019-07-01  8.737163e+06 -2.267210e+03                  NaN
#            2019-08-01  8.255823e+06  2.131805e+03                  NaN
#
#                        capm_Performance  performance_Three_Factor  \
# FundId     Month
# FS00008SZD 2012-01-01          1.507391                  3.652442
#            2012-02-01          1.544497                  1.220171
#            2012-03-01          4.025839                  0.078026
#            2012-04-01          2.647697                  0.989935
#            2012-05-01         -0.066138                 -0.807304
# ...                                 ...                       ...
# FSUSA09WNF 2019-04-01         -3.067829                 -3.546688
#            2019-05-01          3.666930                  4.017213
#            2019-06-01          4.207674                  3.772864
#            2019-07-01          1.134835                  4.536452
#            2019-08-01         -5.479327                 -3.326145
#
#                        performance_Four_Factor Inception Date  \
# FundId     Month
# FS00008SZD 2012-01-01                 1.841484     2009-01-28
#            2012-02-01                 1.155288     2009-01-28
#            2012-03-01                 0.963080     2009-01-28
#            2012-04-01                 1.171659     2009-01-28
#            2012-05-01                -0.354775     2009-01-28
# ...                                        ...            ...
# FSUSA09WNF 2019-04-01                -4.150616     2008-11-11
#            2019-05-01                 5.035920     2008-11-11
#            2019-06-01                 3.199166     2008-11-11
#            2019-07-01                 4.007588     2008-11-11
#            2019-08-01                -2.716709     2008-11-11
#
#                       Equity Style Box (Long)  Age  size_log  esb_l      Month
# FundId     Month
# FS00008SZD 2012-01-01            Large Growth   35  8.416574    2.0 2012-01-01
#            2012-02-01            Large Growth   36  8.475439    2.0 2012-02-01
#            2012-03-01            Large Growth   37  8.487284    2.0 2012-03-01
#            2012-04-01            Large Growth   38  8.536653    2.0 2012-04-01
#            2012-05-01            Large Growth   39  8.576478    2.0 2012-05-01
# ...                                       ...  ...       ...    ...        ...
# FSUSA09WNF 2019-04-01             Large Blend  124  6.910505    3.0 2019-04-01
#            2019-05-01             Large Blend  125  6.901951    3.0 2019-05-01
#            2019-06-01             Large Blend  126  6.937071    3.0 2019-06-01
#            2019-07-01             Large Blend  127  6.941370    3.0 2019-07-01
#            2019-08-01             Large Blend  128  6.916760    3.0 2019-08-01
#
# [301392 rows x 12 columns]

# %%
#xtreg In_wage age 
exog_vars = ['Fund Sustainability','size_log', 'Age']
exog = sm.add_constant(df[exog_vars])

# %%
exog
# Out:
#                        const  Fund Sustainability  size_log  Age
# FundId     Month
# FS00008SZD 2012-01-01    1.0                  NaN  8.416574   35
#            2012-02-01    1.0                  NaN  8.475439   36
#            2012-03-01    1.0                  NaN  8.487284   37
#            2012-04-01    1.0                  NaN  8.536653   38
#            2012-05-01    1.0                  NaN  8.576478   39
# ...                      ...                  ...       ...  ...
# FSUSA09WNF 2019-04-01    1.0                  NaN  6.910505  124
#            2019-05-01    1.0                  NaN  6.901951  125
#            2019-06-01    1.0                40.91  6.937071  126
#            2019-07-01    1.0                  NaN  6.941370  127
#            2019-08-01    1.0                  NaN  6.916760  128
#
# [301392 rows x 4 columns]

# %%
mod = PanelOLS(df.capm_Performance, exog, entity_effects=True, time_effects=True)
mod
# Out:
# PanelOLS
# Num exog: 4, Constant: True
# Entity Effects: True, Time Effects: True, Num Other Effects: 0
# id: 0x7f18de602b10

# %%
res = mod.fit(cov_type='clustered', cluster_entity=True)
res2 = mod.fit()

# %%
print(res)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:       capm_Performance   R-squared:                        0.0002
# Estimator:                   PanelOLS   R-squared (Between):             -0.7186
# No. Observations:              155436   R-squared (Within):              -0.0020
# Date:                Sun, Apr 05 2020   R-squared (Overall):             -0.0357
# Time:                        17:20:02   Log-likelihood                 -3.51e+05
# Cov. Estimator:             Clustered
#                                         F-statistic:                      9.2051
# Entities:                        3262   P-value                           0.0000
# Avg Obs:                       47.651   Distribution:                F(3,152081)
# Min Obs:                       1.0000
# Max Obs:                       91.000   F-statistic (robust):             7.7719
#                                         P-value                           0.0000
# Time periods:                      91   Distribution:                F(3,152081)
# Avg Obs:                       1708.1
# Min Obs:                       556.00
# Max Obs:                       2581.0
#
#                                   Parameter Estimates
# =======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------
# const                  -0.7236     4.1153    -0.1758     0.8604     -8.7895      7.3423
# Fund Sustainability     0.0174     0.0048     3.6207     0.0003      0.0080      0.0268
# size_log               -0.0838     0.0254    -3.3011     0.0010     -0.1336     -0.0341
# Age                     0.0085     0.0326     0.2597     0.7951     -0.0554      0.0724
# =======================================================================================
#
# F-test for Poolability: 87.593
# P-value: 0.0000
# Distribution: F(3351,152081)
#
# Included effects: Entity, Time

# %%
print(res2)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:       capm_Performance   R-squared:                        0.0002
# Estimator:                   PanelOLS   R-squared (Between):             -0.7186
# No. Observations:              155436   R-squared (Within):              -0.0020
# Date:                Sun, Apr 05 2020   R-squared (Overall):             -0.0357
# Time:                        17:20:25   Log-likelihood                 -3.51e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      9.2051
# Entities:                        3262   P-value                           0.0000
# Avg Obs:                       47.651   Distribution:                F(3,152081)
# Min Obs:                       1.0000
# Max Obs:                       91.000   F-statistic (robust):             9.2051
#                                         P-value                           0.0000
# Time periods:                      91   Distribution:                F(3,152081)
# Avg Obs:                       1708.1
# Min Obs:                       556.00
# Max Obs:                       2581.0
#
#                                   Parameter Estimates
# =======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------
# const                  -0.7236     4.4865    -0.1613     0.8719     -9.5171      8.0698
# Fund Sustainability     0.0174     0.0043     4.0670     0.0000      0.0090      0.0258
# size_log               -0.0838     0.0257    -3.2653     0.0011     -0.1341     -0.0335
# Age                     0.0085     0.0356     0.2379     0.8119     -0.0613      0.0782
# =======================================================================================
#
# F-test for Poolability: 87.593
# P-value: 0.0000
# Distribution: F(3351,152081)
#
# Included effects: Entity, Time

# %%
x2 = np.linspace(38, 60, 3276*92)
y2 = [0.02*ix - 0.4699 for ix in x2]
plt.cla()
plt.plot(df['Fund Sustainability'][1000:2000], df['capm_Performance'][1000:2000], ".r")
plt.plot(x2, y2, "-b")
plt.grid(True)
plt.title("Factor Loading First Month: 2012-01")
plt.xlabel("beta_value")
plt.ylabel("Fund Return of All Month")
plt.pause(.5)

# %%
#example
data = pd.read_stata('nlswork.dta')
year = pd.Categorical(data.year)
data = data.set_index(['idcode','year'])
data['year']=year

exog_vars = ['age','tenure','south']
exog = sm.add_constant(data[exog_vars])

mod = PanelOLS(data.ln_wage, exog, entity_effects=True)

res = mod.fit()

res2 = mod.fit(cov_type='clustered', cluster_entity=True)

exog_vars2 = ['age','tenure','south', 'year']
exog2 = sm.add_constant(data[exog_vars2])

mod2 = PanelOLS(data.ln_wage, exog2, entity_effects=True)

res3 = mod2.fit(cov_type='clustered', cluster_entity=True)

# %%
print(res)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                ln_wage   R-squared:                        0.1312
# Estimator:                   PanelOLS   R-squared (Between):              0.1804
# No. Observations:               28093   R-squared (Within):               0.1312
# Date:                Sun, Apr 05 2020   R-squared (Overall):              0.1599
# Time:                        17:15:51   Log-likelihood                   -3263.8
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1177.9
# Entities:                        4699   P-value                           0.0000
# Avg Obs:                       5.9785   Distribution:                 F(3,23391)
# Min Obs:                       1.0000
# Max Obs:                       15.000   F-statistic (robust):             1177.9
#                                         P-value                           0.0000
# Time periods:                      15   Distribution:                 F(3,23391)
# Avg Obs:                       1872.9
# Min Obs:                       1186.0
# Max Obs:                       2242.0
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          1.2837     0.0118     109.22     0.0000      1.2606      1.3067
# age            0.0123     0.0004     29.770     0.0000      0.0115      0.0131
# tenure         0.0210     0.0008     26.174     0.0000      0.0194      0.0225
# south         -0.0725     0.0112    -6.4975     0.0000     -0.0944     -0.0507
# ==============================================================================
#
# F-test for Poolability: 7.4776
# P-value: 0.0000
# Distribution: F(4698,23391)
#
# Included effects: Entity

# %%
print(res2)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                ln_wage   R-squared:                        0.1312
# Estimator:                   PanelOLS   R-squared (Between):              0.1804
# No. Observations:               28093   R-squared (Within):               0.1312
# Date:                Sun, Apr 05 2020   R-squared (Overall):              0.1599
# Time:                        17:15:51   Log-likelihood                   -3263.8
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1177.9
# Entities:                        4699   P-value                           0.0000
# Avg Obs:                       5.9785   Distribution:                 F(3,23391)
# Min Obs:                       1.0000
# Max Obs:                       15.000   F-statistic (robust):             517.42
#                                         P-value                           0.0000
# Time periods:                      15   Distribution:                 F(3,23391)
# Avg Obs:                       1872.9
# Min Obs:                       1186.0
# Max Obs:                       2242.0
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          1.2837     0.0205     62.501     0.0000      1.2434      1.3239
# age            0.0123     0.0007     16.620     0.0000      0.0108      0.0137
# tenure         0.0210     0.0012     17.370     0.0000      0.0186      0.0233
# south         -0.0725     0.0176    -4.1204     0.0000     -0.1070     -0.0380
# ==============================================================================
#
# F-test for Poolability: 7.4776
# P-value: 0.0000
# Distribution: F(4698,23391)
#
# Included effects: Entity

# %%
print(res3)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                ln_wage   R-squared:                        0.1345
# Estimator:                   PanelOLS   R-squared (Between):              0.1818
# No. Observations:               28093   R-squared (Within):               0.1345
# Date:                Sun, Apr 05 2020   R-squared (Overall):              0.1616
# Time:                        17:15:51   Log-likelihood                   -3211.7
# Cov. Estimator:             Clustered
#                                         F-statistic:                      213.62
# Entities:                        4699   P-value                           0.0000
# Avg Obs:                       5.9785   Distribution:                F(17,23377)
# Min Obs:                       1.0000
# Max Obs:                       15.000   F-statistic (robust):             100.45
#                                         P-value                           0.0000
# Time periods:                      15   Distribution:                F(17,23377)
# Avg Obs:                       1872.9
# Min Obs:                       1186.0
# Max Obs:                       2242.0
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          1.2483     0.2347     5.3185     0.0000      0.7883      1.7083
# age            0.0115     0.0123     0.9373     0.3486     -0.0125      0.0355
# tenure         0.0209     0.0012     17.136     0.0000      0.0185      0.0233
# south         -0.0733     0.0177    -4.1351     0.0000     -0.1081     -0.0386
# year.69        0.0725     0.0156     4.6595     0.0000      0.0420      0.1031
# year.70        0.0351     0.0265     1.3252     0.1851     -0.0168      0.0870
# year.71        0.0699     0.0383     1.8231     0.0683     -0.0053      0.1451
# year.72        0.0660     0.0502     1.3131     0.1892     -0.0325      0.1645
# year.73        0.0626     0.0624     1.0027     0.3160     -0.0598      0.1849
# year.75        0.0464     0.0862     0.5389     0.5899     -0.1224      0.2153
# year.77        0.0706     0.1107     0.6380     0.5235     -0.1463      0.2875
# year.78        0.0851     0.1233     0.6903     0.4900     -0.1565      0.3267
# year.80        0.0679     0.1476     0.4603     0.6453     -0.2213      0.3571
# year.82        0.0488     0.1719     0.2840     0.7764     -0.2881      0.3857
# year.83        0.0488     0.1840     0.2654     0.7907     -0.3119      0.4096
# year.85        0.0669     0.2085     0.3211     0.7482     -0.3417      0.4755
# year.87        0.0506     0.2333     0.2167     0.8284     -0.4068      0.5079
# year.88        0.0785     0.2492     0.3149     0.7529     -0.4100      0.5670
# ==============================================================================
#
# F-test for Poolability: 7.4850
# P-value: 0.0000
# Distribution: F(4698,23377)
#
# Included effects: Entity

# %%
dat
