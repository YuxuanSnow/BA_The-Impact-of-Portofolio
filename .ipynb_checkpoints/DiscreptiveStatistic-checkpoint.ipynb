# %%
import numpy as np
import pandas as pd
import pylab as pl
import matplotlib.pyplot as plt
from scipy.stats import mstats

# %%
discreptive_ex_0 = pd.read_excel('Summary Cleaned.xlsx')
table_three = pd.read_excel('Europe_3_Factors.xlsx')
table_one = pd.read_excel('Europe_MOM_Factor.xlsx')
#read the summary, firsty clean the Investment Type, only Open-End Fund reamin

# %%
cols = ["Fund Size","Fund Flow","Fund Return","Fund Sustainability"]
discreptive_ex[cols] = discreptive_ex_0[cols].replace({0:np.nan})

# %%
discreptive_ex_0
# Out:
#         Unnamed: 0      FundId  Fund Code  \
# 0              NaN  FS00008SZD          0
# 1              NaN  FS00008SZD          0
# 2              NaN  FS00008SZD          0
# 3              NaN  FS00008SZD          0
# 4              NaN  FS00008SZD          0
# ...            ...         ...        ...
# 301387         NaN  FSUSA09WNF          0
# 301388         NaN  FSUSA09WNF          0
# 301389         NaN  FSUSA09WNF          0
# 301390         NaN  FSUSA09WNF          0
# 301391         NaN  FSUSA09WNF          0
#
#                                           Fund Legal Name  \
# 0                   BBH Luxembourg Funds Core Select Fund
# 1                   BBH Luxembourg Funds Core Select Fund
# 2                   BBH Luxembourg Funds Core Select Fund
# 3                   BBH Luxembourg Funds Core Select Fund
# 4                   BBH Luxembourg Funds Core Select Fund
# ...                                                   ...
# 301387  T. Rowe Price Funds SICAV - Emerging Europe Eq...
# 301388  T. Rowe Price Funds SICAV - Emerging Europe Eq...
# 301389  T. Rowe Price Funds SICAV - Emerging Europe Eq...
# 301390  T. Rowe Price Funds SICAV - Emerging Europe Eq...
# 301391  T. Rowe Price Funds SICAV - Emerging Europe Eq...
#
#                                           Name Base Currency          ISIN  \
# 0                        BBH Lux Core Select I     US Dollar  LU0407242659
# 1                        BBH Lux Core Select I     US Dollar  LU0407242659
# 2                        BBH Lux Core Select I     US Dollar  LU0407242659
# 3                        BBH Lux Core Select I     US Dollar  LU0407242659
# 4                        BBH Lux Core Select I     US Dollar  LU0407242659
# ...                                        ...           ...           ...
# 301387  T. Rowe Price Emerging Europe Eq I EUR          Euro  LU0382934197
# 301388  T. Rowe Price Emerging Europe Eq I EUR          Euro  LU0382934197
# 301389  T. Rowe Price Emerging Europe Eq I EUR          Euro  LU0382934197
# 301390  T. Rowe Price Emerging Europe Eq I EUR          Euro  LU0382934197
# 301391  T. Rowe Price Emerging Europe Eq I EUR          Euro  LU0382934197
#
#           Domicile Investment Type Primary Prospectus Benchmark   Month  \
# 0       Luxembourg   Open-End Fund               S&P 500 TR USD  2012-1
# 1       Luxembourg   Open-End Fund               S&P 500 TR USD  2012-2
# 2       Luxembourg   Open-End Fund               S&P 500 TR USD  2012-3
# 3       Luxembourg   Open-End Fund               S&P 500 TR USD  2012-4
# 4       Luxembourg   Open-End Fund               S&P 500 TR USD  2012-5
# ...            ...             ...                          ...     ...
# 301387  Luxembourg   Open-End Fund  MSCI EM Europe 10/40 NR EUR  2019-4
# 301388  Luxembourg   Open-End Fund  MSCI EM Europe 10/40 NR EUR  2019-5
# 301389  Luxembourg   Open-End Fund  MSCI EM Europe 10/40 NR EUR  2019-6
# 301390  Luxembourg   Open-End Fund  MSCI EM Europe 10/40 NR EUR  2019-7
# 301391  Luxembourg   Open-End Fund  MSCI EM Europe 10/40 NR EUR  2019-8
#
#            Fund Size     Fund Flow  Fund Return  Fund Sustainability
# 0       2.609599e+08  4.379443e+07     3.497920                 0.00
# 1       2.988403e+08  2.572761e+07     4.657310                 0.00
# 2       3.071028e+08  1.558167e+06     2.243070                 0.00
# 3       3.440745e+08  3.753147e+07    -0.182330                 0.00
# 4       3.771187e+08  4.877692e+07    -4.572510                 0.00
# ...              ...           ...          ...                  ...
# 301387  8.137770e+06 -1.487095e+03     2.976877                 0.00
# 301388  7.979041e+06  8.084123e+02    -1.891875                 0.00
# 301389  8.651099e+06  2.060187e+03     8.407780                40.91
# 301390  8.737163e+06 -2.267210e+03     1.075166                 0.00
# 301391  8.255823e+06  2.131805e+03    -5.497699                 0.00
#
# [301392 rows x 15 columns]

# %%
cols2 = ["Fund Size","Fund Flow","Fund Return","Fund Sustainability"]
average = discreptive_ex.groupby('FundId')[cols2].mean()

# %%
fund_flow = discreptive_ex_0['Fund Flow']
fund_return = discreptive_ex_0['Fund Return']
fund_sus = discreptive_ex_0['Fund Sustainability']

# %%
a = discreptive_ex_0[discreptive_ex_0['Fund Return'] == 0]
a
# Out:
#         Unnamed: 0      FundId  Fund Code  \
# 335            NaN  FSGBR076CL          0
# 336            NaN  FSGBR076CL          0
# 337            NaN  FSGBR076CL          0
# 338            NaN  FSGBR076CL          0
# 339            NaN  FSGBR076CL          0
# ...            ...         ...        ...
# 301166         NaN  FS0000CO7L          0
# 301167         NaN  FS0000CO7L          0
# 301168         NaN  FS0000CO7L          0
# 301169         NaN  FS0000CO7L          0
# 301170         NaN  FS0000CO7L          0
#
#                                           Fund Legal Name  \
# 335                                        Allianz Deluxe
# 336                                        Allianz Deluxe
# 337                                        Allianz Deluxe
# 338                                        Allianz Deluxe
# 339                                        Allianz Deluxe
# ...                                                   ...
# 301166  Allianz Global Investors Fund - Allianz Global...
# 301167  Allianz Global Investors Fund - Allianz Global...
# 301168  Allianz Global Investors Fund - Allianz Global...
# 301169  Allianz Global Investors Fund - Allianz Global...
# 301170  Allianz Global Investors Fund - Allianz Global...
#
#                                             Name Base Currency          ISIN  \
# 335                         Allianz Deluxe A EUR          Euro  LU0256866673
# 336                         Allianz Deluxe A EUR          Euro  LU0256866673
# 337                         Allianz Deluxe A EUR          Euro  LU0256866673
# 338                         Allianz Deluxe A EUR          Euro  LU0256866673
# 339                         Allianz Deluxe A EUR          Euro  LU0256866673
# ...                                          ...           ...           ...
# 301166  Allianz Global Smaller Companies WT9 USD     US Dollar  LU1449864740
# 301167  Allianz Global Smaller Companies WT9 USD     US Dollar  LU1449864740
# 301168  Allianz Global Smaller Companies WT9 USD     US Dollar  LU1449864740
# 301169  Allianz Global Smaller Companies WT9 USD     US Dollar  LU1449864740
# 301170  Allianz Global Smaller Companies WT9 USD     US Dollar  LU1449864740
#
#           Domicile Investment Type       Primary Prospectus Benchmark  \
# 335     Luxembourg   Open-End Fund  EURO STOXX Pers&Hushld Gds NR USD
# 336     Luxembourg   Open-End Fund  EURO STOXX Pers&Hushld Gds NR USD
# 337     Luxembourg   Open-End Fund  EURO STOXX Pers&Hushld Gds NR USD
# 338     Luxembourg   Open-End Fund  EURO STOXX Pers&Hushld Gds NR USD
# 339     Luxembourg   Open-End Fund  EURO STOXX Pers&Hushld Gds NR USD
# ...            ...             ...                                ...
# 301166  Luxembourg   Open-End Fund             MSCI World SMID NR USD
# 301167  Luxembourg   Open-End Fund             MSCI World SMID NR USD
# 301168  Luxembourg   Open-End Fund             MSCI World SMID NR USD
# 301169  Luxembourg   Open-End Fund             MSCI World SMID NR USD
# 301170  Luxembourg   Open-End Fund             MSCI World SMID NR USD
#
#           Month   Fund Size     Fund Flow  Fund Return  Fund Sustainability
# 335     2016-12         0.0 -1.796358e+05          0.0                  0.0
# 336      2017-1         0.0  0.000000e+00          0.0                  0.0
# 337      2017-2         0.0  0.000000e+00          0.0                  0.0
# 338      2017-3         0.0  0.000000e+00          0.0                  0.0
# 339      2017-4         0.0  0.000000e+00          0.0                  0.0
# ...         ...         ...           ...          ...                  ...
# 301166   2016-3         0.0  0.000000e+00          0.0                  0.0
# 301167   2016-4         0.0  0.000000e+00          0.0                  0.0
# 301168   2016-5         0.0  0.000000e+00          0.0                  0.0
# 301169   2016-6         0.0  0.000000e+00          0.0                  0.0
# 301170   2016-7  26718042.0  2.671804e+07          0.0                  0.0
#
# [58645 rows x 15 columns]

# %%
def winsorize_removeString(array, left_limit, right_limit):
    
    nan = []
    an = []
    order = []
    a = 0
    array_expand = []
    a_win = [0.0] * len(array)
    
    for i in range(len(array)):
        if array[i] == 0:
            nan.append(i)
        else:
            array_expand.append(array[i])
            an.append(i)
            order.append(a)
            a += 1
            
    print(an[-1])
    
    a_winex = scipy.stats.mstats.winsorize(array_expand, limits=[left_limit, right_limit])
    
    for x,y in zip(an, range(len(an))):
        a_win[x] = a_winex[y]
    
    '''

    if a == len(array):
        a_win = scipy.stats.mstats.winsorize(array_expand, limits=[left_limit, right_limit])
    else:
        if len(array_expand) != 0:
            a_winex = scipy.stats.mstats.winsorize(array_expand, limits=[left_limit, right_limit])

            for x in range(len(array)):
                for y in range(len(an)):
                    for z in range(len(nan)):
                        if nan[z] == x:
                            a_win[x] = 0
                            print('a')
                    if an[y] == x:
                        a_win[x] = a_winex[y]
                        print("b")

        else:
            a_win = [0] * len(array)
    '''
        
    return a_win

# %%
flow_win = winsorize_removeString(fund_flow, 0.01, 0.01)
return_win = winsorize_removeString(fund_return, 0.01, 0.01)
sus_win = winsorize_removeString(fund_sus, 0.01, 0.01)
# Out:
# 301391
# 119436333.412378

# %%
#table_three.std()
#table_three.min()
#table_three.max()
#table_one.mean()
#table_one.std()
#table_one.min()
#table_one.max()
table_three.mean()
# Out:
# Unnamed: 0    201541.108696
# Mkt-RF             0.646196
# SMB                0.145435
# HML               -0.111413
# RF                 0.047717
# dtype: float64

# %%
average_value = discreptive_ex[cols2].mean()
standard_deviation = discreptive_ex[cols2].std()
min_value = discreptive_ex[cols2].min()
max_value = discreptive_ex[cols2].max()

# %%
hist_size = discreptive_ex['Fund Size'].plot.hist(bins=1000,ylim=(0,4000),grid=True)

# %%
col_size = discreptive_ex['Fund Size'].tolist()
MIN, MAX = 1000000.0, 20000000000.0
pl.figure()
pl.hist(col_size, bins = 10 ** np.linspace(np.log10(MIN), np.log10(MAX), 1000))
pl.gca().set_xscale("log")
pl.grid()
pl.show()

# %%
hist_size = discreptive_ex['Fund Flow'].plot.hist(bins=1000,ylim=(0,2000),grid=True)

# %%
hist_return = discreptive_ex['Fund Return'].hist(bins=1000)

# %%
hist_sus = discreptive_ex['Fund Sustainability'].hist(bins=1000)

# %%
smaller_7 = average[average['Fund Size'] < 10000000]

larger_7 = average[average['Fund Size'] >= 10000000]
ten_hundred = larger_7[larger_7['Fund Size'] < 100000000]

larger_8 = average[average['Fund Size'] >= 100000000]
hundred_thousend = larger_8[larger_8['Fund Size'] < 1000000000]

larger_9 = average[average['Fund Size'] >= 1000000000]
thousend_tenthousend = larger_9[larger_9['Fund Size'] < 10000000000]

larger_10 = average[average['Fund Size'] >= 10000000000]
tenthousend_hundredthousend = larger_10[larger_10['Fund Size'] < 100000000000]

larger_11 = average[average['Fund Size'] >= 100000000000]

# %%
sus_med = average['Fund Sustainability'].median()
low_sus = average[average['Fund Sustainability'] < sus_med]
high_sus = average[average['Fund Sustainability'] > sus_med]
